# %%
import numpy as np

# %%
x=np.array([1,-3,5,7])

# %%
def f(x):
  return np.exp(x)/np.sum(np.exp(x))

# %%
result=f(x)

# %%
np.sum(result)
# Out:
# 1.0

# %%
o=np.array([
            [1,-3,5,7],
            [5,1,-9,-4]
            ])

# %%
def g(x):
  return np.exp(o)/np.sum(np.exp(o),axis=1).reshape([-1,1])

# %%
result1=g(o)

# %%
np.sum(result1,axis=1)
# Out:
# array([1., 1.])

# %%
g(o)
# Out:
# array([[2.17843444e-03, 3.98994185e-05, 1.18938490e-01, 8.78843176e-01],
#        [9.81893992e-01, 1.79840158e-02, 8.16473054e-07, 1.21175345e-04]])
