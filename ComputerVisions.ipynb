# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as img
from PIL import Image

# %%
im=img.imread("OTTER.png")

# %%
im.shape
# Out:
# (894, 850, 3)

# %%
plt.figure(figsize=(5,5))
plt.imshow(im)
plt.show()

# %%
x=np.arange(0,1,.001)

def f(x):
  return np.sin(10*x)

  plt.plot(x,f(x))
  plt.show()

# %%
im2=np.zeros([894,853,3])
for y in range(0,894):
  for x in range(0,850):
    im2[y,x]=f(im[y,x])
    
plt.figure(figsize=(5,5))
plt.imshow(im2)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
