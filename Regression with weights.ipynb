# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.metrics import mean_squared_error

# %%
X0=np.ones(20).reshape([-1,1])
X1=np.random.uniform(0,10,size=20).reshape([-1,1])
X2=np.random.uniform(0,10,size=20).reshape([-1,1])
X = np.hstack([X0,X1,X2])
Y= 5*X1 +3*X2 +2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5168cfe6a95d> in <module>()
# ----> 1 X0=np.ones(20).reshape([-1,1])
#       2 X1=np.random.uniform(0,10,size=20).reshape([-1,1])
#       3 X2=np.random.uniform(0,10,size=20).reshape([-1,1])
#       4 X = np.hstack([X0,X1,X2])
#       5 Y= 5*X1 +3*X2 +2
#
# NameError: name 'np' is not defined

# %% [markdown]
# $
# y=w_2x_2+w_1x_1+w_0
# $

# %%
def loss(w):
  Yhat=np.matmul(X,w)
  return np.mean(Y-Yhat)**2

def dloss(w):
  Yhat=np.matmul(X,w)
  return np.mean(-2*(Y-Yhat)*X,axis=0)#get two averages

def train(lr,epochs):
  w= np.array([0,0,0]).reshape([-1,1])
  for i in range (0,epochs):
    w= w-lr*dloss(w) 
    print(w)

#train(.01,5000)

# %%
regr=linear_model.LinearRegression()
regr.fit(X,Y)
# Out:
# LinearRegression()

# %%
regr.intercept_
# Out:
# array([0.31142598])

# %%
regr.coef_
# Out:
# array([[0.        , 5.14373375, 2.8149963 ]])
